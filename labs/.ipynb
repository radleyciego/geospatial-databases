# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
bk_acs = pd.read_csv('/Users/radleyciego/GitHub/geospatial-databases/data/Kings_Education_Attainment_ACS_17_5YR_B15003/ACS_17_5YR_B15003.csv')
bk_acs
# Out:
#                      GEO.id       GEO.id2  \
# 0     1500000US360470001001  360470001001
# 1     1500000US360470001002  360470001002
# 2     1500000US360470001003  360470001003
# 3     1500000US360470001004  360470001004
# 4     1500000US360470002001  360470002001
# ...                     ...           ...
# 2080  1500000US360471502003  360471502003
# 2081  1500000US360471522001  360471522001
# 2082  1500000US360471522002  360471522002
# 2083  1500000US360471522003  360471522003
# 2084  1500000US360479901000  360479901000
#
#                                       GEO.display-label  HD01_VD01  HD02_VD01  \
# 0     Block Group 1, Census Tract 1, Kings County, N...        295        179
# 1     Block Group 2, Census Tract 1, Kings County, N...        867        189
# 2     Block Group 3, Census Tract 1, Kings County, N...       1183        217
# 3     Block Group 4, Census Tract 1, Kings County, N...       1207        187
# 4     Block Group 1, Census Tract 2, Kings County, N...        999        185
# ...                                                 ...        ...        ...
# 2080  Block Group 3, Census Tract 1502, Kings County...        576        131
# 2081  Block Group 1, Census Tract 1522, Kings County...        784        182
# 2082  Block Group 2, Census Tract 1522, Kings County...        884        214
# 2083  Block Group 3, Census Tract 1522, Kings County...        950        201
# 2084  Block Group 0, Census Tract 9901, Kings County...          0         11
#
#       HD01_VD02  HD02_VD02  HD01_VD03  HD02_VD03  HD01_VD04  ...  HD01_VD21  \
# 0             0         11          0         11          0  ...         18
# 1             0         11          0         11          0  ...         62
# 2             0         11          0         11          0  ...         28
# 3             0         11          0         11          0  ...         36
# 4            61         41          0         11          0  ...         51
# ...         ...        ...        ...        ...        ...  ...        ...
# 2080          8         13          0         11          0  ...         23
# 2081          9         17          0         11          0  ...         26
# 2082          0         11          2          9          0  ...         70
# 2083          3          3          9         15          0  ...         61
# 2084          0         11          0         11          0  ...          0
#
#       HD02_VD21  HD01_VD22  HD02_VD22  HD01_VD23  HD02_VD23  HD01_VD24  \
# 0            28         66         49         54         59         34
# 1            57        251        117        150         89         72
# 2            34        612        223        338        132         82
# 3            44        185         91        314        121        128
# 4            34         60         43         26         28          0
# ...         ...        ...        ...        ...        ...        ...
# 2080         30        253         89         69         45         56
# 2081         33        294        109         81         38         24
# 2082         74        244        122        235        104         50
# 2083         52        239        111        227         77         63
# 2084         11          0         11          0         11          0
#
#       HD02_VD24  HD01_VD25  HD02_VD25
# 0            40          0         11
# 1            58         32         49
# 2            58         10         16
# 3            93         42         42
# 4            11          7          9
# ...         ...        ...        ...
# 2080         45          0         11
# 2081         27          4          9
# 2082         34          0         11
# 2083         41         54         35
# 2084         11          0         11
#
# [2085 rows x 53 columns]

# %%
bk_acs = bk_acs.rename(columns=str.lower)
bk_acs
# Out:
#                      geo.id       geo.id2  \
# 0     1500000US360470001001  360470001001
# 1     1500000US360470001002  360470001002
# 2     1500000US360470001003  360470001003
# 3     1500000US360470001004  360470001004
# 4     1500000US360470002001  360470002001
# ...                     ...           ...
# 2080  1500000US360471502003  360471502003
# 2081  1500000US360471522001  360471522001
# 2082  1500000US360471522002  360471522002
# 2083  1500000US360471522003  360471522003
# 2084  1500000US360479901000  360479901000
#
#                                       geo.display-label  hd01_vd01  hd02_vd01  \
# 0     Block Group 1, Census Tract 1, Kings County, N...        295        179
# 1     Block Group 2, Census Tract 1, Kings County, N...        867        189
# 2     Block Group 3, Census Tract 1, Kings County, N...       1183        217
# 3     Block Group 4, Census Tract 1, Kings County, N...       1207        187
# 4     Block Group 1, Census Tract 2, Kings County, N...        999        185
# ...                                                 ...        ...        ...
# 2080  Block Group 3, Census Tract 1502, Kings County...        576        131
# 2081  Block Group 1, Census Tract 1522, Kings County...        784        182
# 2082  Block Group 2, Census Tract 1522, Kings County...        884        214
# 2083  Block Group 3, Census Tract 1522, Kings County...        950        201
# 2084  Block Group 0, Census Tract 9901, Kings County...          0         11
#
#       hd01_vd02  hd02_vd02  hd01_vd03  hd02_vd03  hd01_vd04  ...  hd01_vd21  \
# 0             0         11          0         11          0  ...         18
# 1             0         11          0         11          0  ...         62
# 2             0         11          0         11          0  ...         28
# 3             0         11          0         11          0  ...         36
# 4            61         41          0         11          0  ...         51
# ...         ...        ...        ...        ...        ...  ...        ...
# 2080          8         13          0         11          0  ...         23
# 2081          9         17          0         11          0  ...         26
# 2082          0         11          2          9          0  ...         70
# 2083          3          3          9         15          0  ...         61
# 2084          0         11          0         11          0  ...          0
#
#       hd02_vd21  hd01_vd22  hd02_vd22  hd01_vd23  hd02_vd23  hd01_vd24  \
# 0            28         66         49         54         59         34
# 1            57        251        117        150         89         72
# 2            34        612        223        338        132         82
# 3            44        185         91        314        121        128
# 4            34         60         43         26         28          0
# ...         ...        ...        ...        ...        ...        ...
# 2080         30        253         89         69         45         56
# 2081         33        294        109         81         38         24
# 2082         74        244        122        235        104         50
# 2083         52        239        111        227         77         63
# 2084         11          0         11          0         11          0
#
#       hd02_vd24  hd01_vd25  hd02_vd25
# 0            40          0         11
# 1            58         32         49
# 2            58         10         16
# 3            93         42         42
# 4            11          7          9
# ...         ...        ...        ...
# 2080         45          0         11
# 2081         27          4          9
# 2082         34          0         11
# 2083         41         54         35
# 2084         11          0         11
#
# [2085 rows x 53 columns]

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/learnsql')
bk_acs.to_sql('bk_acs_5y', engine)
# Out:
# 85
